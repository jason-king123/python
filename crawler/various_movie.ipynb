# %%
import requests
from lxml import etree
import parsel
import csv
import re
import time as t

headers = {
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Cookie' : 'bid=jRrJ4GZ1pfY; _pk_id.100001.4cf6=48a1331be8322404.1713623669.; _pk_ses.100001.4cf6=1; ap_v=0,6.0; __utma=30149280.392054908.1713623670.1713623670.1713623670.1; __utmc=30149280; __utmz=30149280.1713623670.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); __utma=223695111.231643814.1713623670.1713623670.1713623670.1; __utmb=223695111.0.10.1713623670; __utmc=223695111; __utmz=223695111.1713623670.1.1.utmcsr=(direct)|utmccn=(direct)|utmcmd=(none); __gads=ID=d3a2c4bf7e90ebe3:T=1713623673:RT=1713623673:S=ALNI_MZjwWfSQsAMDelBtY5EU6ghe-KHWA; __gpi=UID=00000de50870f7bb:T=1713623673:RT=1713623673:S=ALNI_MZh9XA-c_svEd6-RdVypnon7GFBBA; __eoi=ID=b622308785fd9187:T=1713623673:RT=1713623673:S=AA-AfjZEUKBYY9RHIcPBTok4oFf3; ll="118282"; _vwo_uuid_v2=DB853DE0C9E2302BF81133F566EC7D2BD|13bf265f4576e9e538d5f79662f1e940; __utmb=30149280.4.9.1713623735317; FCNEC=%5B%5B%22AKsRol8_AOnOvjGIS4ME6FtLpW8p36JViTwIJy4aQwmNSCfywFWoIdeqOXRi0xqPm_SKojTIQPzDLWYjeypMvpCf7lYtp8RacIpbgLj3JCxAWAksMtiU71_1nTI1pJfUBjAR2Im3ZNQ1Xwxvca3_dyqSMvkSCIxUGA%3D%3D%22%5D%5D'
}
comments_dict = {}
page = 0
movie = 35633600

while True:
    if movie >= 35633700:
        break
    url = f'https://movie.douban.com/subject/{movie}/comments?start={page}&limit=50&sort=new_score&status=P'
    print(url)
    res = requests.get(url=url, headers=headers).text
    selector = parsel.Selector(res)
    comment_list = selector.css('.comment-item')
    if len(comment_list) == 0:
        movie += 1
        continue
    for i, comment in enumerate(comment_list):
        index = i + page
        comments_dict[index] = {
            'name' : '',
            'content' : '',
            'stars' : 0,
            'upvote' : 0,
            'time' : 0,
            'location' : ''
                            }
        try:
            name = comment.css('.comment-info a::text').get().strip()
            content = comment.css('.comment-content span::text').get().strip()
            upvote = comment.css('.votes::text').get()
            time = comment.css('.comment-time').attrib['title'].split(' ')[0]
            location = comment.css('.comment-location::text').get()

            class_attribute = comment.css('.rating::attr(class)').get()
            stars = re.search(r'\d+', class_attribute).group()[0]

            comments_dict[index]['name'] = name
            comments_dict[index]['content'] = content
            comments_dict[index]['stars'] = stars
            comments_dict[index]['upvote'] = upvote
            comments_dict[index]['time'] = time
            comments_dict[index]['location'] = location
        except Exception as e:
            continue

    page += 50
    t.sleep(1)

print("====================================")
print(len(comments_dict))
# Out:
# https://movie.douban.com/subject/35633600/comments?start=0&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=50&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=100&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=150&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=200&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=250&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=300&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=350&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=400&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=450&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=500&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633600/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633601/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633602/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633603/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633604/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633605/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633606/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633607/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633608/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633609/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633610/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633611/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633612/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633613/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633614/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633615/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633616/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633617/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633618/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633619/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633620/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633621/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633622/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633623/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633624/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633625/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633626/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633627/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633628/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633629/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633630/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633631/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633632/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633633/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633634/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633635/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633636/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633637/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633638/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633639/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633640/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633641/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633642/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633643/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633644/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633645/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633646/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633647/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633648/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633649/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633650/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633651/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633652/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633653/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633654/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633655/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633656/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633657/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633658/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633659/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633660/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633661/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633662/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633663/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633664/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633665/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633666/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633667/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633668/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633669/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633670/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633671/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633672/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633673/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633674/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633675/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633676/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633677/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633678/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633679/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633680/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633681/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633682/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633683/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633684/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633685/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633686/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633687/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633688/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633689/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633690/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633691/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633692/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633693/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633694/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633695/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633696/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633697/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633698/comments?start=550&limit=50&sort=new_score&status=P
# https://movie.douban.com/subject/35633699/comments?start=550&limit=50&sort=new_score&status=P
# ====================================
# 11

# %%
comments_dict
# Out:
# {0: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  50: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  100: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  150: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  200: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  250: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  300: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  350: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  400: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  450: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''},
#  500: {'name': '',
#   'content': '',
#   'stars': 0,
#   'upvote': 0,
#   'time': 0,
#   'location': ''}}
